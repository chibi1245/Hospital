# %% [markdown]
# <a href="https://colab.research.google.com/github/chibi1245/Hospital/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.linear_model import LinearRegression
area=[[500],[700],[800],[2200]]
price=[5,7,8,2]

# %%
model=LinearRegression()

# %%
model.fit(area,price)
# Out:
# LinearRegression()

# %%
from sklearn import cluster
from sklearn.cluster import  KMeans
data=[[1,2],[2,3],[3,4],[10,10]]
model=KMeans(n_clusters=3)
model.fit(data)
prediction=model.predict([[2,3]])
print(model.labels_)
# Out:
# [2 0 0 1]

# %%
from sklearn.linear_model import LinearRegression
tempreture=[[20],[30],[40],[50]]
icecream=[100,200,300,400]
model=LinearRegression()
model.fit(tempreture,icecream)
prediction=model.predict([[20]])
print("prediton of theses is:",prediction)
# Out:
# prediton of theses is: [100.]

# %%
 from sklearn.tree import DecisionTreeClassifier
 salary=[[2000],[3400],[4000],[5000]]
 local=[0,0,1,1]
 model=DecisionTreeClassifier()
 model.fit(salary,local)
 prediction=model.predict([[6000]])
 print("prediton of theses is:",prediction)
# Out:
# prediton of theses is: [1]

# %%
 import pandas as pd
 import matplotlib.pyplot as plt
 from sklearn.cluster import KMeans
 from sklearn.preprocessing import LabelEncoder
 df=pd.read_csv("sales.csv")
 encoder=LabelEncoder()
 df['loyalty_encoded']=encoder.fit_transform(df['loyalty_tier'])
 print(df[['loyalty_tier','loyalty_encoded']].head())
 x=df[['age','loyalty_encoded']]
 model=KMeans(n_clusters=3,random_state=42)
 model.fit(x)
 df['clusters']=model.labels_

 print(model.cluster_centers_)
 plt.figure( figsize=(8,5))
 plt.scatter(df['age'],df['loyalty_encoded'],c=df['clusters'],cmap='rainbow')
 plt.scatter(model.cluster_centers_[:,0],model.cluster_centers_[:,1],s=200,marker='x',color='black')
 plt.xlabel('age')
 plt.ylabel('loyalty_tier')
 plt.yticks([0,1,2],['gold','silver','bronze'])
 plt.show()
# Out:
#   loyalty_tier  loyalty_encoded
# 0       Bronze                0
# 1       Silver                3
# 2       Silver                3
# 3       Silver                3
# 4       Silver                3
# [[34.58076133  0.92589974]
#  [46.76750959  0.91885965]
#  [23.18103549  0.933002  ]]

# %%
 import pandas as pd
 from sklearn.model_selection import train_test_split
 from sklearn.preprocessing import LabelEncoder
 from sklearn.linear_model import LogisticRegression
 from sklearn.metrics import accuracy_score
 from sklearn.metrics import confusion_matrix
 df=pd.read_csv("sales.csv")
 encoder=LabelEncoder()
 df['loyalty_encoded']=encoder.fit_transform(df['loyalty_tier'])
 df['gender_encoded']=encoder.fit_transform(df['gender'])
 df['country']=encoder.fit_transform(df['country'])
 df['channel_encoded']=encoder.fit_transform(df['acquisition_channel'])
 x=df[['age','gender_encoded','country','channel_encoded']]
 y=df['loyalty_encoded']
 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
 model=LogisticRegression(max_iter=1000)
 model.fit(x_train,y_train)
 prediction=model.predict(x_test)
 accuracy=accuracy_score(y_test,prediction)
 print(accuracy)
 matrix=confusion_matrix(y_test,prediction)
 print(matrix)
# Out:
# 0.6004
# [[12008     0     0     0]
#  [ 2383     0     0     0]
#  [  636     0     0     0]
#  [ 4973     0     0     0]]

# %%
 prediction=model.predict([[800]])
 print("prediton of theses is:",prediction)
# Out:
# prediton of theses is: [6.17679558]
